# %% [markdown]
# ## Decay Law and Other Functions
# \begin{equation}
#  A      (t)=A_{0}e^{-\lambda t}
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt

Ao=50 # Initial Activity of radioactive substance in Curie
#Half Life of Ir192= 74 Years

t = np.linspace(0,74,10)
A = Ao*np.exp(-0.693*t/74)

#xerr = np.random.random_sample(10)
yerr = np.random.random_sample(10)

fig, ax = plt.subplots()

ax.errorbar(t, A,
            
            yerr=yerr,
            fmt='-o',capsize=5)


ax.set_xlabel('Time (Year)')
ax.set_ylabel('Activity (Curie)')
ax.set_title(' Decay Scheme')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
Ao=50 # Initial Activity of radioactive substance in Curie
#Half Life of Ir192= 74 Years
t = np.linspace(0,74,20)
A = Ao*np.exp(-0.693*t/74)
xerr = 0.3 #year
yerr = 5 # Curie

fig, ax = plt.subplots()

ax.errorbar(t, A,
            xerr=xerr,
            yerr=yerr,
            fmt='-o', color='blue',
             ecolor='black', elinewidth=2, capsize=2)

ax.set_xlabel('Time (Year)')
ax.set_ylabel('Activity (Curie)')
ax.set_title(' Decay Scheme')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
df = pd.read_csv('D.csv')
df
# Out:
#   Source  HalfL_days  Energy_MeV  Range_Steel (mm)
# 0   Co60      1934.5       1.250                200
# 1   Se75       120.0       0.970                 28
# 2  Cs137     10950.0       0.660                100
# 3  Ir192        74.0       0.355                 70
# 4  Th170     47450.0       0.072                 12
# 5  Yb169        30.0       0.053                 12

# %%
df.describe().T
# Out:
#                    count          mean           std     min       25%  \
# HalfL_days           6.0  10093.083333  18782.683936  30.000  85.50000
# Energy_MeV           6.0      0.560000      0.488143   0.053   0.14275
# Range_Steel (mm)     6.0     70.333333     72.513907  12.000  16.00000
#
#                          50%        75%       max
# HalfL_days         1027.2500  8696.1250  47450.00
# Energy_MeV            0.5075     0.8925      1.25
# Range_Steel (mm)     49.0000    92.5000    200.00

# %%
plt.figure(figsize = [8,6])
plt.plot(df.HalfL_days,df['Energy_MeV'])
plt.xlabel('Half Life (days)')
plt.ylabel('Energy(MeV)')
plt.title('Energy Versus Half Life')
plt.show()

# %%
plt.figure(figsize = [8,6])
plt.plot(df.Energy_MeV,df['Range_Steel (mm) '])
plt.xlabel('Energy (MeV)')
plt.ylabel('Thickness of Steel (mm)')
plt.title('Energy Versus Thickness')
plt.show()

# %% [markdown]
# ## Plot Four functions plots in a single call to plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
x = np.arange(1., 5., 0.4)

# red dashes, blue squares, green triangles and reverse dashes with opposite triangle
plt.plot(x, x, 'r--', x, x**2, 'bs', x, x**3, 'g^', x,1/x,'v--')

plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np


x = np.linspace(0, 10, 1000)

fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
plt.ylabel('trigronometic function')
plt.xlabel('x(radian)')

ax.axis('equal')
leg = ax.legend();
